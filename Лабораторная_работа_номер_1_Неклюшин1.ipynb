# %% [markdown]
# # Пример Использования MARKDOWN
#
#
#
# 1.  Неклюшин
# 2. ![Случайная картинка.jpg](data:image/jpeg;base64,...)
# 3.
# **1**|**2**|**3**
# :---:|:---:|:---:
# **a**|**b**|**c**
# 4. https://docs.google.com/spreadsheets/d/1-fHDOnuvCdszYsKZFy75tB3B55ov4YvPTKBCn14Vx3c/edit?usp=share_link
